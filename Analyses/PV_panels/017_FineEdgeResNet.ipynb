# %%
from matplotlib import pyplot as plt
import cnn_utils as cnn
import pv_panel_utils
import tensorflow as tf
import numpy as np

# %matplotlib inline

np.random.seed(42)

# %%
images, scores, labels, query_images, query_scores = pv_panel_utils.import_data(skeleton = True)
print('Images and score masks successfully read.')
# Out:
# Images and score masks successfully read.

# %%
f, axs = plt.subplots(1, 2, figsize = (15, 7))
axs[0].imshow(images[1, :, :, 0], cmap = 'gray'); axs[0].axis('off')
axs[1].imshow(scores[1, :, :, 0], cmap = 'gray'); axs[1].axis('off');
#axs[2].imshow(skeletonize(scores[1, :, :, 0]), cmap = 'gray');

# %%
def define_variables(self):
    variables = {
                    'F0_1': cnn.BatchNormalizedConvLayer(1, 1, 8, residual_layer = False),
                    'F1_1': cnn.BatchNormalizedConvLayer(3, 8, 8, residual_layer = True),
                    'F1_2': cnn.BatchNormalizedConvLayer([40, 10], 8, 8, residual_layer = True),
                    'F2_1': cnn.BatchNormalizedConvLayer(3, 8, 16, residual_layer = False),
                    'F3_1': cnn.BatchNormalizedConvLayer(3, 16, 8, residual_layer = False),
                    'F4_1': cnn.BatchNormalizedConvLayer(5, 8, 8, residual_layer = True),
        
                    'S0_1': cnn.BatchNormalizedConvLayer(3, 8, 2, residual_layer = False),
                    'S1_1': cnn.BatchNormalizedConvLayer(3, 16, 2, residual_layer = False),
                    'S2_1': cnn.BatchNormalizedConvLayer(3, 16, 2, residual_layer = False),
                    'S3_1': cnn.BatchNormalizedConvLayer(3, 8, 2, residual_layer = False),
                    'S4_1': cnn.BatchNormalizedConvLayer(3, 8, 2, residual_layer = False),
        
                    'O5_1': cnn.BatchNormalizedConvLayer(16, 10, 10, residual_layer = True),
        
                    'O6_1': cnn.BatchNormalizedConvLayer(3, 10, 2, activate = False, residual_layer = False)
                }
    return variables

def W185_P52k_ResMask(self, mode, variables):
    """
        Defines sequences of operations constituting network. Refers to variables defined by <variables> dict.
    """
    # Input layer
    self.ops['F0_1'] = variables['F0_1'].apply(mode, self.images)
    self.ops['S0_1'] = variables['S0_1'].apply(mode, self.ops['F0_1'])
    
    # First layer
    self.ops['F1_1'] = variables['F1_1'].apply(mode, self.ops['F0_1'])
    self.ops['F1_2'] = variables['F1_2'].apply(mode, self.ops['F0_1']) # Tall conv.
    self.ops['C1_1'] = tf.concat([self.ops['F1_1'], self.ops['F1_2']], axis = -1)
    self.ops['S1_1'] = variables['S1_1'].apply(mode, self.ops['C1_1'])
    
    # Second Layer
    self.ops['F2_1'] = variables['F2_1'].apply(mode, self.ops['F1_1'])
    self.ops['S2_1'] = variables['S2_1'].apply(mode, self.ops['F2_1'])
    
    # Third layer
    self.ops['F3_1'] = variables['F3_1'].apply(mode, self.ops['F2_1'])
    self.ops['S3_1'] = variables['S3_1'].apply(mode, self.ops['F3_1'])
    
    # Fourth layer
    self.ops['F4_1'] = variables['F4_1'].apply(mode, self.ops['F3_1'])
    self.ops['S4_1'] = variables['S4_1'].apply(mode, self.ops['F4_1'])
    
    # Combining of all skip layers : x8 16 x 16 x 6 filters
    self.ops['C5_1'] = tf.concat([ self.ops['S0_1'], self.ops['S1_1'], self.ops['S2_1'],
                                   self.ops['S3_1'], self.ops['S4_1']], axis = -1)
    
    self.ops['O5_1'] = variables['O5_1'].apply(mode, self.ops['C5_1'])
    
    # Logit layer
    self.ops['logits'] = variables['O6_1'].apply(mode, self.ops['O5_1'])
    
    return self.ops['logits']

# %% [markdown]
# NOTE: THIS NETWORK DOES NOT USE A COMPATIBILITY PENALTY.

# %%
model = cnn.CNNModel(define_variables, W185_P52k_ResMask, model_id = 'W185_P52k_RotSkeletonResMask')
model.compile_graph(score_compatibility = False)
model.train(batch_size = 16,
            training_steps = 10001,
            training_images = images,
            training_scores = scores,
            training_labels = labels,
            query_images = query_images,
            query_scores = query_scores)
# Out:
# Training initialized.
#
#
# Mean minibatch cross-entropy @ step  100 : 0.646
# Mean minibatch cross-entropy @ step  200 : 0.599
# Mean minibatch cross-entropy @ step  300 : 0.553
# Mean minibatch cross-entropy @ step  400 : 0.509
# Mean minibatch cross-entropy @ step  500 : 0.466
# Mean minibatch cross-entropy @ step  600 : 0.426
# Mean minibatch cross-entropy @ step  700 : 0.389
# Mean minibatch cross-entropy @ step  800 : 0.355
# Mean minibatch cross-entropy @ step  900 : 0.322
# Mean minibatch cross-entropy @ step 1000 : 0.292
# Mean minibatch cross-entropy @ step 1100 : 0.266
# Mean minibatch cross-entropy @ step 1200 : 0.241
# Mean minibatch cross-entropy @ step 1300 : 0.220
# Mean minibatch cross-entropy @ step 1400 : 0.198
# Mean minibatch cross-entropy @ step 1500 : 0.180
# Mean minibatch cross-entropy @ step 1600 : 0.164
# Mean minibatch cross-entropy @ step 1700 : 0.148
# Mean minibatch cross-entropy @ step 1800 : 0.135
# Mean minibatch cross-entropy @ step 1900 : 0.123
# Mean minibatch cross-entropy @ step 2000 : 0.112
# Mean minibatch cross-entropy @ step 2100 : 0.100
# Mean minibatch cross-entropy @ step 2200 : 0.091
# Mean minibatch cross-entropy @ step 2300 : 0.083
# Mean minibatch cross-entropy @ step 2400 : 0.077
# Mean minibatch cross-entropy @ step 2500 : 0.070
# Mean minibatch cross-entropy @ step 2600 : 0.067
# Mean minibatch cross-entropy @ step 2700 : 0.057
# Mean minibatch cross-entropy @ step 2800 : 0.053
# Mean minibatch cross-entropy @ step 2900 : 0.049
# Mean minibatch cross-entropy @ step 3000 : 0.044
# Mean minibatch cross-entropy @ step 3100 : 0.042
# Mean minibatch cross-entropy @ step 3200 : 0.036
# Mean minibatch cross-entropy @ step 3300 : 0.036
# Mean minibatch cross-entropy @ step 3400 : 0.031
# Mean minibatch cross-entropy @ step 3500 : 0.032
# Mean minibatch cross-entropy @ step 3600 : 0.027
# Mean minibatch cross-entropy @ step 3700 : 0.023
# Mean minibatch cross-entropy @ step 3800 : 0.024
# Mean minibatch cross-entropy @ step 3900 : 0.021
# Mean minibatch cross-entropy @ step 4000 : 0.019
# Mean minibatch cross-entropy @ step 4100 : 0.021
# Mean minibatch cross-entropy @ step 4200 : 0.018
# Mean minibatch cross-entropy @ step 4300 : 0.016
# Mean minibatch cross-entropy @ step 4400 : 0.014
# Mean minibatch cross-entropy @ step 4500 : 0.013
# Mean minibatch cross-entropy @ step 4600 : 0.013
# Mean minibatch cross-entropy @ step 4700 : 0.011
# Mean minibatch cross-entropy @ step 4800 : 0.013
# Mean minibatch cross-entropy @ step 4900 : 0.010
# Mean minibatch cross-entropy @ step 5000 : 0.009
# Mean minibatch cross-entropy @ step 5100 : 0.012
# Mean minibatch cross-entropy @ step 5200 : 0.010
# Mean minibatch cross-entropy @ step 5300 : 0.011
# Mean minibatch cross-entropy @ step 5400 : 0.012
# Mean minibatch cross-entropy @ step 5500 : 0.012
# Mean minibatch cross-entropy @ step 5600 : 0.008
# Mean minibatch cross-entropy @ step 5700 : 0.009
# Mean minibatch cross-entropy @ step 5800 : 0.008
# Mean minibatch cross-entropy @ step 5900 : 0.010
# Mean minibatch cross-entropy @ step 6000 : 0.006
# Mean minibatch cross-entropy @ step 6100 : 0.008
# Mean minibatch cross-entropy @ step 6200 : 0.008
# Mean minibatch cross-entropy @ step 6300 : 0.006
# Mean minibatch cross-entropy @ step 6400 : 0.008
# Mean minibatch cross-entropy @ step 6500 : 0.010
# Mean minibatch cross-entropy @ step 6600 : 0.008
# Mean minibatch cross-entropy @ step 6700 : 0.008
# Mean minibatch cross-entropy @ step 6800 : 0.010
# Mean minibatch cross-entropy @ step 6900 : 0.006
# Mean minibatch cross-entropy @ step 7000 : 0.006
# Mean minibatch cross-entropy @ step 7100 : 0.008
# Mean minibatch cross-entropy @ step 7200 : 0.009
# Mean minibatch cross-entropy @ step 7300 : 0.007
# Mean minibatch cross-entropy @ step 7400 : 0.007
# Mean minibatch cross-entropy @ step 7500 : 0.004
# Mean minibatch cross-entropy @ step 7600 : 0.008
# Mean minibatch cross-entropy @ step 7700 : 0.004
# Mean minibatch cross-entropy @ step 7800 : 0.006
# Mean minibatch cross-entropy @ step 7900 : 0.005
# Mean minibatch cross-entropy @ step 8000 : 0.004
# Mean minibatch cross-entropy @ step 8100 : 0.006
# Mean minibatch cross-entropy @ step 8200 : 0.007
# Mean minibatch cross-entropy @ step 8300 : 0.006
# Mean minibatch cross-entropy @ step 8400 : 0.006
# Mean minibatch cross-entropy @ step 8500 : 0.005
# Mean minibatch cross-entropy @ step 8600 : 0.006
# Mean minibatch cross-entropy @ step 8700 : 0.010
# Mean minibatch cross-entropy @ step 8800 : 0.007
# Mean minibatch cross-entropy @ step 8900 : 0.006
# Mean minibatch cross-entropy @ step 9000 : 0.008
# Mean minibatch cross-entropy @ step 9100 : 0.006
# Mean minibatch cross-entropy @ step 9200 : 0.005
# Mean minibatch cross-entropy @ step 9300 : 0.004
# Mean minibatch cross-entropy @ step 9400 : 0.007
# Mean minibatch cross-entropy @ step 9500 : 0.005
# Mean minibatch cross-entropy @ step 9600 : 0.005
# Mean minibatch cross-entropy @ step 9700 : 0.008
# Mean minibatch cross-entropy @ step 9800 : 0.007
# Mean minibatch cross-entropy @ step 9900 : 0.005
# Mean minibatch cross-entropy @ step 10000: 0.011
